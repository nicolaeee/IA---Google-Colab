# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolaeee/IA---Google-Colab/blob/main/Tema4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from mlxtend.frequent_patterns import fpgrowth, association_rules

# 1. Încărcare și transformare în format One-Hot Encoding
# df_fao = ... (datele încărcate de pe site-ul FAO)
basket = (df_fao.groupby(['IndividualID', 'FoodCategory'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('IndividualID'))

# Transformare în valori booleene (1 dacă a consumat, 0 dacă nu)
def encode_units(x):
    return 1 if x > 0 else 0
basket_sets = basket.applymap(encode_units)

# 2. Aplicare FP-Growth
frequent_itemsets = fpgrowth(basket_sets, min_support=0.05, use_colnames=True)

# 3. Generare Reguli
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.2)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...
